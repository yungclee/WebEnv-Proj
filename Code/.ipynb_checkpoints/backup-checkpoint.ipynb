# %%
import sys
sys.path.append('~/Code/') 
from DataPreProcessor import DataPreProcessor
from DataRetriever import DataRetriever
from DataVisualization import DataVisualizer
import pandas as pd
import numpy as np
'''
start_date = '20191101'
end_date = '20191201'
getlog = DataRetriever(start_date, end_date, 'ray', '0420')
getlog.get_deviceID()
df = getlog.retrieve()
'''
# Out:
# "\nstart_date = '20191101'\nend_date = '20191201'\ngetlog = DataRetriever(start_date, end_date, 'ray', '0420')\ngetlog.get_deviceID()\ndf = getlog.retrieve()\n"

# %%
df = pd.read_hdf('../Data/raw_data.h5')

# %%
import importlib
import DataVisualization
import DataPreProcessor
importlib.reload(DataVisualization)
importlib.reload(DataPreProcessor)
# Out:
# <module 'DataPreProcessor' from '/Users/raylee/WebEnv-Proj/Code/DataPreProcessor.py'>

# %%
from DataPreProcessor import DataPreProcessor
proc = DataPreProcessor(df, 'LogTime')
proc.df.columns
# Out:
# Index(['LogTime', 'DC_cold_aisle', 'DC_hot_aisle', 'AC_avg_usage',
#        'IT_avg_usage', 'DC_avg_usage', 'PUE', 'AC0_current', 'AC1_current',
#        'Dev1_ambinet_temp', 'Dev1_CPU_temp', 'Dev1_power_temp',
#        'Dev1_fan0_speed', 'Dev1_fan1_speed', 'Dev1_fan2_speed',
#        'Dev1_fan3_speed', 'Dev1_fan4_speed', 'Dev1_fan5_speed',
#        'Dev1_power_reading', 'Dev0_CPU_loading', 'Dev0_ambinet_temp',
#        'Dev0_CPU_temp', 'Dev0_power_temp', 'Dev0_fan0_speed',
#        'Dev0_fan1_speed', 'Dev0_fan2_speed', 'Dev0_fan3_speed',
#        'Dev0_fan4_speed', 'Dev0_fan5_speed', 'Dev0_power_reading',
#        'Dev1_CPU_loading', 'Dev2_ambinet_temp', 'Dev2_CPU_temp',
#        'Dev2_power_temp', 'Dev2_fan0_speed', 'Dev2_fan1_speed',
#        'Dev2_fan2_speed', 'Dev2_fan3_speed', 'Dev2_fan4_speed',
#        'Dev2_fan5_speed', 'Dev2_power_reading', 'Dev2_CPU_loading',
#        'FileServer_CPU_loading', 'ERP_CPU_loading', 'WebEnv_CPU_loading'],
#       dtype='object')

# %%
proc.df.DC_avg_usage.fillna(method = 'ffill', limit = 1)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 252987    57.49
# 252989    57.49
# 252995    57.49
# 252997    57.49
# 253003    57.49
# Name: DC_avg_usage, Length: 95519, dtype: float64

# %%
proc.drop_empty_rows()
proc.drop_duplicates()
proc.impute_all()
# Out:
# Warning: [DC_cold_aisle] 80.174% data are missing, should not be imputed. Exiting...
# Warning: [DC_hot_aisle] 80.174% data are missing, should not be imputed. Exiting...
# Warning: column imputed has no missing values.
#                    Columns Impute_method Nan_count Forward_filled  \
# 0            DC_cold_aisle          None      None           None
# 1             DC_hot_aisle          None      None           None
# 2             AC_avg_usage        linear        96             91
# 3             IT_avg_usage        linear        96             91
# 4             DC_avg_usage        linear        96             91
# 5                      PUE        linear        96             91
# 6              AC0_current        linear        96             91
# 7              AC1_current    FillMedian        96             91
# 8        Dev1_ambinet_temp        linear     15087           5188
# 9            Dev1_CPU_temp    FillMedian     15087           5188
# 10         Dev1_power_temp        linear     15087           5188
# 11         Dev1_fan0_speed    FillMedian     15087           5188
# 12         Dev1_fan1_speed    FillMedian     15087           5188
# 13         Dev1_fan2_speed    FillMedian     15087           5188
# 14         Dev1_fan3_speed    FillMedian     15087           5188
# 15         Dev1_fan4_speed    FillMedian     15087           5188
# 16         Dev1_fan5_speed        linear     15087           5188
# 17      Dev1_power_reading        linear     15087           5188
# 18        Dev0_CPU_loading        linear     15081           5183
# 19       Dev0_ambinet_temp        linear     15101           5200
# 20           Dev0_CPU_temp    FillMedian     15101           5200
# 21         Dev0_power_temp        linear     15101           5200
# 22         Dev0_fan0_speed        linear     15101           5200
# 23         Dev0_fan1_speed        linear     15101           5200
# 24         Dev0_fan2_speed        linear     15101           5200
# 25         Dev0_fan3_speed        linear     15101           5200
# 26         Dev0_fan4_speed        linear     15101           5200
# 27         Dev0_fan5_speed        linear     15101           5200
# 28      Dev0_power_reading        linear     15101           5200
# 29        Dev1_CPU_loading    FillMedian     15094           5197
# 30       Dev2_ambinet_temp        linear     15114           5210
# 31           Dev2_CPU_temp    FillMedian     15114           5210
# 32         Dev2_power_temp        linear     15114           5210
# 33         Dev2_fan0_speed    FillMedian     15114           5210
# 34         Dev2_fan1_speed    FillMedian     15114           5210
# 35         Dev2_fan2_speed    FillMedian     15114           5210
# 36         Dev2_fan3_speed        linear     15114           5210
# 37         Dev2_fan4_speed        linear     15114           5210
# 38         Dev2_fan5_speed        linear     15114           5210
# 39      Dev2_power_reading     quadratic     15114           5210
# 40        Dev2_CPU_loading    FillMedian     15109           5205
# 41  FileServer_CPU_loading    FillMedian        10              4
# 42         ERP_CPU_loading    FillMedian        10              4
# 43      WebEnv_CPU_loading    FillMedian        10              4
# 44                 imputed          None      None           None
#
#    Backward_filled Imputed_count
# 0             None          None
# 1             None          None
# 2                1             4
# 3                1             4
# 4                1             4
# 5                1             4
# 6                1             4
# 7                1             4
# 8             1574          8325
# 9             1574          8325
# 10            1574          8325
# 11            1574          8325
# 12            1574          8325
# 13            1574          8325
# 14            1574          8325
# 15            1574          8325
# 16            1574          8325
# 17            1574          8325
# 18            1574          8324
# 19            1574          8327
# 20            1574          8327
# 21            1574          8327
# 22            1574          8327
# 23            1574          8327
# 24            1574          8327
# 25            1574          8327
# 26            1574          8327
# 27            1574          8327
# 28            1574          8327
# 29            1573          8324
# 30            1575          8329
# 31            1575          8329
# 32            1575          8329
# 33            1575          8329
# 34            1575          8329
# 35            1575          8329
# 36            1575          8329
# 37            1575          8329
# 38            1575          8329
# 39            1575          8329
# 40            1574          8330
# 41               2             4
# 42               2             4
# 43               2             4
# 44            None          None

# %%
from copy import copy
work_df = copy(proc.df)

# %%
import matplotlib.pyplot as plt
# specify columns to plot
groups = [ x for x in range(1,len(work_df.columns))]
i = 1
# plot each column
plt.figure(figsize = (20,40))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(work_df.values[:, group])
    plt.title(work_df.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
col_missingval = work_df.columns[work_df.isna().any()].tolist()
col_novar = work_df.drop(columns = 'LogTime').columns[work_df.var() == 0].tolist()
corr_matrix = work_df.drop(columns = col_missingval + col_novar).corr()

# %%
from DataVisualization import DataVisualizer
vis = DataVisualizer(work_df)

# %%
vis.plt_corr()

# %%
vis.var_heatmap('Dev1_power_temp', cmap = 'viridis', smoothing = True)

# %%
vis.var_heatmap("AC0_current", cmap = 'viridis')

# %%
vis.var_heatmap("Dev1_ambinet_temp")

# %%
vis.df
# Out:
#        AC0_current  AC1_current  AC_avg_usage  DC_avg_usage  DC_cold_aisle  \
# 0             2.78          0.0        11.810         66.93            NaN
# 1             2.99          0.0        11.810         66.93            NaN
# 2             2.98          0.0        11.810         66.93           28.3
# 3             2.98          0.0        11.810         66.93            NaN
# 4             3.18          0.0        11.810         66.93            NaN
# ...            ...          ...           ...           ...            ...
# 41708         2.09          0.0         4.329         57.49            NaN
# 41709         0.79          0.0         4.329         57.49            NaN
# 41710         0.60          0.0         4.329         57.49           26.3
# 41711         2.08          0.0         4.329         57.49            NaN
# 41712         2.08          0.0         4.329         57.49            NaN
#
#        DC_hot_aisle  Dev0_CPU_loading  Dev0_CPU_temp  Dev0_ambinet_temp  \
# 0               NaN          6.790000           40.0               24.0
# 1               NaN          6.790000           40.0               24.0
# 2              33.1          6.702222           40.0               24.0
# 3               NaN          6.614444           40.0               24.0
# 4               NaN          6.526667           40.0               24.0
# ...             ...               ...            ...                ...
# 41708           NaN         10.010000           40.0               26.0
# 41709           NaN          9.060000           40.0               26.0
# 41710          33.3          9.060000           40.0               26.0
# 41711           NaN         15.690000           40.0               26.0
# 41712           NaN         10.370000           40.0               25.0
#
#        Dev0_fan0_speed  ...  Dev2_fan5_speed  Dev2_power_reading  \
# 0            58.000000  ...             54.0          345.000000
# 1            58.000000  ...             54.0          345.000000
# 2            57.944444  ...             54.0          344.913684
# 3            57.888889  ...             54.0          344.741052
# 4            57.833333  ...             54.0          344.482104
# ...                ...  ...              ...                 ...
# 41708        58.000000  ...             57.0          309.000000
# 41709        58.000000  ...             57.0          307.000000
# 41710        58.000000  ...             57.0          307.000000
# 41711        58.000000  ...             57.0          306.000000
# 41712        58.000000  ...             57.0          304.000000
#
#        Dev2_power_temp  ERP_CPU_loading  FileServer_CPU_loading  IT_avg_usage  \
# 0                 40.0              2.5                     0.0         55.12
# 1                 40.0              2.5                     0.0         55.12
# 2                 40.0              0.0                     4.0         55.12
# 3                 40.0              1.0                    13.5         55.12
# 4                 40.0              0.5                     1.5         55.12
# ...                ...              ...                     ...           ...
# 41708             41.0              0.0                    20.0         53.16
# 41709             40.0              0.0                     9.0         53.16
# 41710             40.0              0.5                     0.0         53.16
# 41711             40.0              2.0                     0.0         53.16
# 41712             40.0              0.0                    12.0         53.16
#
#                   LogTime    PUE  WebEnv_CPU_loading  imputed
# 0     2019-11-03 00:00:00  1.214                28.0     True
# 1     2019-11-03 00:01:00  1.214                28.0     True
# 2     2019-11-03 00:02:00  1.214                28.0     True
# 3     2019-11-03 00:03:00  1.214                28.0     True
# 4     2019-11-03 00:04:00  1.214                28.0     True
# ...                   ...    ...                 ...      ...
# 41708 2019-12-01 23:56:00  1.081                28.0     True
# 41709 2019-12-01 23:57:00  1.081                28.0     True
# 41710 2019-12-01 23:58:00  1.081                28.0    False
# 41711 2019-12-01 23:59:00  1.081                28.0     True
# 41712 2019-12-02 00:00:00  1.081                28.0     True
#
# [41713 rows x 46 columns]

# %%
vis.df[['Dev0_ambinet_temp','Dev1_ambinet_temp','Dev2_ambinet_temp','AC0_current']].corr()
vis.df[['Dev0_power_temp','Dev1_power_temp','Dev2_power_temp','AC0_current']].corr()
# Out:
#                  Dev0_power_temp  Dev1_power_temp  Dev2_power_temp  \
# Dev0_power_temp         1.000000         0.470642         0.370063
# Dev1_power_temp         0.470642         1.000000         0.217459
# Dev2_power_temp         0.370063         0.217459         1.000000
# AC0_current            -0.187416        -0.100873        -0.038907
#
#                  AC0_current
# Dev0_power_temp    -0.187416
# Dev1_power_temp    -0.100873
# Dev2_power_temp    -0.038907
# AC0_current         1.000000

# %%
from matplotlib import cm
w = np.hanning(60)

groups = work_df.set_index('LogTime')['Dev1_ambinet_temp'].groupby(pd.Grouper(freq='D'))
months = pd.concat([pd.DataFrame(x[1].values) for x in groups], axis=1).apply(lambda x : np.convolve(w/w.sum(),x,mode='valid'))
months = pd.DataFrame(months)
months = months.T
months.shape

fig = plt.figure(figsize=(30,5))
ax = fig.add_subplot(111)
cax = ax.matshow(months, interpolation=None, cmap="viridis", aspect='auto')
fig.colorbar(cax)
ax.xaxis.set_ticks_position('bottom')
plt.xlabel('Minutes')
plt.ylabel('Days')
plt.show()

# %%
work_df.set_index('LogTime')['Dev1_ambinet_temp'].groupby(pd.Grouper(freq='D')).apply(lambda x: len(x))
# Out:
# LogTime
# 2019-11-03    1440
# 2019-11-04    1440
# 2019-11-05    1440
# 2019-11-06    1414
# 2019-11-07    1440
# 2019-11-08    1440
# 2019-11-09    1440
# 2019-11-10    1440
# 2019-11-11    1440
# 2019-11-12    1440
# 2019-11-13    1440
# 2019-11-14    1440
# 2019-11-15    1440
# 2019-11-16    1440
# 2019-11-17    1440
# 2019-11-18    1440
# 2019-11-19    1440
# 2019-11-20    1418
# 2019-11-21    1440
# 2019-11-22    1440
# 2019-11-23    1440
# 2019-11-24    1440
# 2019-11-25    1440
# 2019-11-26    1440
# 2019-11-27    1440
# 2019-11-28    1440
# 2019-11-29    1440
# 2019-11-30    1440
# 2019-12-01    1440
# 2019-12-02       1
# Freq: D, Name: Dev1_ambinet_temp, dtype: int64

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
## set.seed()
numpy.random.seed(420)

# %%
# adopt and modified from  https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
# convert series to supervised learning
def prep_input(data, scaler, n_in = 1, n_out =1, dropna = True, key = 'ambinet', time_var = 'LogTime'):
    '''
    Variables: 
        1. data: input dataframe to convert to LSTM ready input
        2. key: used to indicate and generate the response
        3. time_var: the column that is specified to be the timestamp
        4. scaler: the method requires a scaler to normalize the data set.
    Usage:
        input must be a dataframe with a time_var indicating the DateTime index to be used, 
        will perform the follwing actions: 
            1. create response column by integrating the values containing keyword `key` and drop those.
            2. drop columns contain NaN to avoid scaler error
            3. use MinMaxScaler to scale all values to [0,1]
            4. create input sequence(t-n, ...., t-1) and response requence(t,...t+n) 
    '''
    ## first create response columns
    df = pd.DataFrame(data).set_index(time_var)
    response_var = [x for x in data.columns if key in x]
    df['res'] = df[response_var].apply(lambda x: x.mean(), axis = 1).values
    df.drop(columns = response_var, inplace = True)
    
    ## drop columnms that contain Nan to avoid error 
    
    df.dropna(axis =1, inplace = True)
    
    ## scale the vars to be in [0,1] range
    
    df = pd.DataFrame(scaler.fit_transform(df.values.astype(np.float32)), columns = df.columns)
    
    n_vars = 0 if type(df) is list else df.shape[1] - 1
    cols, names = [], []
    ## input sequence (t-n, ....t-1) 
    for t in range(n_in, 0, -1):
        cols.append(df.drop(columns = 'res').shift(t)) ## explanatory vars
        cols.append(df['res'].shift(t)) ## response var
        names += ['var{}(t-{})'.format(j, t) for j in range(n_vars) ]
        names += ['res(t-{})'.format(t)]
    ## response sequence (t,... t+n)
    for t in range(0, n_out):
        cols.append(df['res'].shift(-t))
        if t ==0:
            names += ['res(t)']
        else: 
            names += ['res(t+{})'.format(t)]
    agg = pd.concat(cols, axis = 1)
    agg.columns = names
    
    if dropna:
        agg.dropna(inplace=True)
    return agg

# %%
scaler = MinMaxScaler(feature_range= (0,1))
lstm_in_2 = prep_input(vis.df, scaler, n_out = 2)
lstm_in_10 = prep_input(vis.df, scaler, n_out = 10)

# %%
lstm_in_10.shape
# Out:
# (41703, 51)

# %%
lstm_in = lstm_in_10

# %%
def ts_train_test_split(data, perc = 0.8):
    '''
    Usage: 
        Analog of scipy train test split, while applying on time series data the data has to be continuous, thus the customized function.
        note that the response has to be in the last column
    '''
    length = len(data) if type(data) is list else data.shape[0]
    index = int(length * perc)
    train = data[:index, :]
    test = data[index: , :]
    X_train, y_train = train[:, :-1], train[:, -1]
    X_test, y_test = test[:, :-1], test[:, -1]
    
    ## importnat the X need to be reshape into 3D array for LSTM input [samples, timesteps, features]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
    print("Using {}% as training and {}% test".format(100*perc, round(100*(1-perc))) )
    print("X reshape to have 3D: [samples, timesteps, features]")
    for i in ['X_train', 'X_test', 'y_train','y_test']:
        print('{}: shape{}'.format(i, eval(i).shape))
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = ts_train_test_split(lstm_in.values)
# Out:
# Using 80.0% as training and 20% test
# X reshape to have 3D: [samples, timesteps, features]
# X_train: shape(33362, 1, 50)
# X_test: shape(8341, 1, 50)
# y_train: shape(33362,)
# y_test: shape(8341,)

# %%
def LSTM_model(X_train, X_val, y_train, y_val, params):
    from keras import optimizers
    
    #network
    model = Sequential()
    model.add(LSTM(41, return_sequences= False, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(1))
    RMS = optimizers.RMSprop(learning_rate=params['lr'], rho=0.9)
    model.compile(loss='mse',
                  optimizer= RMS,
                  metrics=['mae'])
    # fit network
    history = model.fit(X_train, y_train, epochs= params['epochs'], batch_size= params['batch_size'], validation_data=(X_test, y_test),verbose = 0)
    
    return history, model

# %%
from keras import optimizers
model = Sequential()
model.add(LSTM(41, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
RMS = optimizers.RMSprop(learning_rate= 0.0001, rho=0.9)
model.compile(loss='mse',
              optimizer= RMS,
              metrics=['mae'])
# fit network
history = model.fit(X_train, y_train, epochs= 60, batch_size= 100, validation_data=(X_test, y_test),verbose = 2)
# Out:
# Train on 33362 samples, validate on 8341 samples
# Epoch 1/60
#  - 1s - loss: 0.0218 - mae: 0.1070 - val_loss: 0.0056 - val_mae: 0.0581
# Epoch 2/60
#  - 0s - loss: 0.0046 - mae: 0.0496 - val_loss: 0.0046 - val_mae: 0.0514
# Epoch 3/60
#  - 0s - loss: 0.0039 - mae: 0.0444 - val_loss: 0.0043 - val_mae: 0.0489
# Epoch 4/60
#  - 0s - loss: 0.0034 - mae: 0.0408 - val_loss: 0.0041 - val_mae: 0.0470
# Epoch 5/60
#  - 1s - loss: 0.0031 - mae: 0.0380 - val_loss: 0.0038 - val_mae: 0.0449
# Epoch 6/60
#  - 1s - loss: 0.0029 - mae: 0.0361 - val_loss: 0.0037 - val_mae: 0.0439
# Epoch 7/60
#  - 0s - loss: 0.0027 - mae: 0.0346 - val_loss: 0.0038 - val_mae: 0.0433
# Epoch 8/60
#  - 0s - loss: 0.0026 - mae: 0.0336 - val_loss: 0.0038 - val_mae: 0.0434
# Epoch 9/60
#  - 0s - loss: 0.0026 - mae: 0.0327 - val_loss: 0.0037 - val_mae: 0.0420
# Epoch 10/60
#  - 0s - loss: 0.0025 - mae: 0.0321 - val_loss: 0.0038 - val_mae: 0.0431
# Epoch 11/60
#  - 0s - loss: 0.0025 - mae: 0.0316 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 12/60
#  - 0s - loss: 0.0024 - mae: 0.0312 - val_loss: 0.0035 - val_mae: 0.0402
# Epoch 13/60
#  - 0s - loss: 0.0024 - mae: 0.0308 - val_loss: 0.0035 - val_mae: 0.0400
# Epoch 14/60
#  - 0s - loss: 0.0024 - mae: 0.0306 - val_loss: 0.0035 - val_mae: 0.0396
# Epoch 15/60
#  - 0s - loss: 0.0023 - mae: 0.0304 - val_loss: 0.0037 - val_mae: 0.0415
# Epoch 16/60
#  - 0s - loss: 0.0023 - mae: 0.0302 - val_loss: 0.0037 - val_mae: 0.0416
# Epoch 17/60
#  - 0s - loss: 0.0023 - mae: 0.0300 - val_loss: 0.0036 - val_mae: 0.0404
# Epoch 18/60
#  - 0s - loss: 0.0023 - mae: 0.0299 - val_loss: 0.0037 - val_mae: 0.0417
# Epoch 19/60
#  - 0s - loss: 0.0023 - mae: 0.0297 - val_loss: 0.0036 - val_mae: 0.0419
# Epoch 20/60
#  - 0s - loss: 0.0023 - mae: 0.0296 - val_loss: 0.0034 - val_mae: 0.0388
# Epoch 21/60
#  - 0s - loss: 0.0023 - mae: 0.0295 - val_loss: 0.0036 - val_mae: 0.0411
# Epoch 22/60
#  - 0s - loss: 0.0023 - mae: 0.0295 - val_loss: 0.0036 - val_mae: 0.0404
# Epoch 23/60
#  - 0s - loss: 0.0023 - mae: 0.0293 - val_loss: 0.0036 - val_mae: 0.0405
# Epoch 24/60
#  - 0s - loss: 0.0023 - mae: 0.0293 - val_loss: 0.0035 - val_mae: 0.0397
# Epoch 25/60
#  - 0s - loss: 0.0023 - mae: 0.0293 - val_loss: 0.0034 - val_mae: 0.0390
# Epoch 26/60
#  - 1s - loss: 0.0023 - mae: 0.0293 - val_loss: 0.0035 - val_mae: 0.0399
# Epoch 27/60
#  - 0s - loss: 0.0022 - mae: 0.0292 - val_loss: 0.0033 - val_mae: 0.0381
# Epoch 28/60
#  - 0s - loss: 0.0022 - mae: 0.0291 - val_loss: 0.0034 - val_mae: 0.0383
# Epoch 29/60
#  - 0s - loss: 0.0022 - mae: 0.0291 - val_loss: 0.0034 - val_mae: 0.0390
# Epoch 30/60
#  - 0s - loss: 0.0022 - mae: 0.0291 - val_loss: 0.0036 - val_mae: 0.0410
# Epoch 31/60
#  - 0s - loss: 0.0022 - mae: 0.0290 - val_loss: 0.0036 - val_mae: 0.0412
# Epoch 32/60
#  - 0s - loss: 0.0022 - mae: 0.0290 - val_loss: 0.0034 - val_mae: 0.0393
# Epoch 33/60
#  - 0s - loss: 0.0022 - mae: 0.0290 - val_loss: 0.0035 - val_mae: 0.0400
# Epoch 34/60
#  - 0s - loss: 0.0022 - mae: 0.0289 - val_loss: 0.0033 - val_mae: 0.0380
# Epoch 35/60
#  - 0s - loss: 0.0022 - mae: 0.0289 - val_loss: 0.0034 - val_mae: 0.0395
# Epoch 36/60
#  - 0s - loss: 0.0022 - mae: 0.0289 - val_loss: 0.0034 - val_mae: 0.0390
# Epoch 37/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0033 - val_mae: 0.0379
# Epoch 38/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0038 - val_mae: 0.0432
# Epoch 39/60
#  - 0s - loss: 0.0022 - mae: 0.0289 - val_loss: 0.0037 - val_mae: 0.0422
# Epoch 40/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0033 - val_mae: 0.0381
# Epoch 41/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0035 - val_mae: 0.0406
# Epoch 42/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0034 - val_mae: 0.0391
# Epoch 43/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0034 - val_mae: 0.0385
# Epoch 44/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0033 - val_mae: 0.0379
# Epoch 45/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0035 - val_mae: 0.0407
# Epoch 46/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0034 - val_mae: 0.0387
# Epoch 47/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0033 - val_mae: 0.0377
# Epoch 48/60
#  - 0s - loss: 0.0022 - mae: 0.0288 - val_loss: 0.0033 - val_mae: 0.0379
# Epoch 49/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0033 - val_mae: 0.0379
# Epoch 50/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0033 - val_mae: 0.0382
# Epoch 51/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0034 - val_mae: 0.0396
# Epoch 52/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0033 - val_mae: 0.0384
# Epoch 53/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0033 - val_mae: 0.0377
# Epoch 54/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0036 - val_mae: 0.0415
# Epoch 55/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0038 - val_mae: 0.0439
# Epoch 56/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0036 - val_mae: 0.0423
# Epoch 57/60
#  - 0s - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0033 - val_mae: 0.0385
# Epoch 58/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0034 - val_mae: 0.0391
# Epoch 59/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0032 - val_mae: 0.0379
# Epoch 60/60
#  - 0s - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0033 - val_mae: 0.0388

# %%
p = {'lr': [0.0001, 0.001, 0.01, 0.1],
     'first_neuron':[50],
     'batch_size': [20, 30, 40],
     'epochs': [60, 90, 120],
     'activation':['tanh','relu'],
     'recurrent_activation': ['sigmoid']}

# %%
X_test.shape
# Out:
# (8341, 1, 50)

# %%
X_test[-10:,:].shape
# Out:
# (10, 1, 50)

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.title('LSTM one layer model')
plt.show()

# %%
test_predict = model.predict(X_test)

# %%
X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0c1cdefd54ea> in <module>
# ----> 1 X_test
#
# NameError: name 'X_test' is not defined

# %%
y_inv_scaler = MinMaxScaler()
y_inv_scaler.min_,y_inv_scaler.scale_ = scaler.min_[-1], scaler.scale_[-1]

# %%
scaler.min_

# %%
y_forecast = y_inv_scaler.inverse_transform(test_predict).reshape(-1)
y_original = y_inv_scaler.inverse_transform(y_train.reshape(1,-1)).reshape(-1)
y_obs = y_inv_scaler.inverse_transform(y_test.reshape(1,-1)).reshape(-1)

# %%
test_predict.shape

# %%
plt.figure(figsize=(30,5))
his_time = 100
pred_time = 1000
plt.plot(range(his_time),y_original[-his_time:])
plt.plot(range(his_time, pred_time+ his_time), y_obs[0:pred_time])
plt.plot(range(his_time, pred_time+ his_time), y_forecast[0:pred_time])
plt.legend(('history','observed','forecast'),prop={'size': 20})
